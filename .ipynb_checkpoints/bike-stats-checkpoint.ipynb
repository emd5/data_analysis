# %% [markdown]
# # Bike Share Data Journals

# %% [markdown]
# [Cycle Share](https://www.kaggle.com/pronto/cycle-share-dataset)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import csv

# %%
trip_df = pd.read_csv('./trip.csv', error_bad_lines=False, )
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %% [markdown]
# Note: Checking to see the tables rows and columns

# %%
trip_df.head()
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender  birthyear
# 0          CBD-06         PS-04   Member    Male     1960.0
# 1          CBD-06         PS-04   Member    Male     1970.0
# 2          CBD-06         PS-04   Member  Female     1988.0
# 3          CBD-06         PS-04   Member  Female     1977.0
# 4          CBD-06         PS-04   Member    Male     1971.0

# %%
df_weather = pd.read_csv('./cycle-share-dataset/weather.csv', error_bad_lines=False)

# %%
df_weather.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity   ...    Mean_Sea_Level_Pressure_In  \
# 0             68            46   ...                         29.79
# 1             78            63   ...                         29.75
# 2             77            67   ...                         29.71
# 3             61            36   ...                         29.95
# 4             72            46   ...                         29.78
#
#    Min_Sea_Level_Pressure_In  Max_Visibility_Miles  Mean_Visibility_Miles  \
# 0                      29.65                    10                     10
# 1                      29.54                    10                      9
# 2                      29.51                    10                      9
# 3                      29.81                    10                     10
# 4                      29.73                    10                     10
#
#    Min_Visibility_Miles  Max_Wind_Speed_MPH  Mean_Wind_Speed_MPH  \
# 0                     4                  13                    4
# 1                     3                  10                    5
# 2                     3                  18                    7
# 3                    10                   9                    4
# 4                     6                   8                    3
#
#    Max_Gust_Speed_MPH Precipitation_In  Events
# 0                  21             0.00    Rain
# 1                  17             0.11    Rain
# 2                  25             0.45    Rain
# 3                   -             0.00    Rain
# 4                   -             0.14    Rain
#
# [5 rows x 21 columns]

# %%
station_df = pd.read_csv('./cycle-share-dataset/station.csv', error_bad_lines=False)
station_df.head()
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
# 3      BT-05  2nd Ave & Blanchard St  47.613110 -122.344208   10/13/2014
# 4     CBD-03      7th Ave & Union St  47.610731 -122.332447   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN
# 2                 16               NaN                 16               NaN
# 3                 14               NaN                 14               NaN
# 4                 20               NaN                 20               NaN

# %% [markdown]
# Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
df_weather['Date'] = pd.to_datetime(df_weather['Date'])
df_weather['Month'] = df_weather['Date'].dt.month
df_weather.head()
# Out:
#         Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0 2014-10-13                 71                62.0                54
# 1 2014-10-14                 63                59.0                55
# 2 2014-10-15                 62                58.0                54
# 3 2014-10-16                 71                61.0                52
# 4 2014-10-17                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity  ...    Min_Sea_Level_Pressure_In  \
# 0             68            46  ...                        29.65
# 1             78            63  ...                        29.54
# 2             77            67  ...                        29.51
# 3             61            36  ...                        29.81
# 4             72            46  ...                        29.73
#
#    Max_Visibility_Miles  Mean_Visibility_Miles  Min_Visibility_Miles  \
# 0                    10                     10                     4
# 1                    10                      9                     3
# 2                    10                      9                     3
# 3                    10                     10                    10
# 4                    10                     10                     6
#
#    Max_Wind_Speed_MPH  Mean_Wind_Speed_MPH  Max_Gust_Speed_MPH  \
# 0                  13                    4                  21
# 1                  10                    5                  17
# 2                  18                    7                  25
# 3                   9                    4                   -
# 4                   8                    3                   -
#
#    Precipitation_In Events  Month
# 0              0.00   Rain     10
# 1              0.11   Rain     10
# 2              0.45   Rain     10
# 3              0.00   Rain     10
# 4              0.14   Rain     10
#
# [5 rows x 22 columns]

# %%
avg_precip = pd.DataFrame(df_weather[['Month','Precipitation_In']]).groupby(df_weather.Month).mean()
avg_precip
# Out:
#        Month  Precipitation_In
# Month
# 1          1          0.143548
# 2          2          0.168421
# 3          3          0.156935
# 4          4          0.051333
# 5          5          0.012419
# 6          6          0.030500
# 7          7          0.012097
# 8          8          0.018226
# 9          9          0.041000
# 10        10          0.189000
# 11        11          0.187833
# 12        12          0.236290

# %% [markdown]
# What is the average trip duration for a borrowed bicycle?

# %%
trip_mins = trip_df['tripduration'].mean() //60
print(f'Average trip duration was {trip_mins} minutes')
# Out:
# Average trip duration was 19.0 minutes

# %% [markdown]
# What’s the most common age of a bicycle-sharer?

# %%
trip_df['age'] = dt.now().year - trip_df['birthyear']
pd.DataFrame(trip_df['age'].mode(), columns=['Most Common Age'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-24d8a62fbe56> in <module>()
# ----> 1 trip_df['age'] = dt.Now().year - trip_df['birthyear']
#       2 pd.DataFrame(trip_df['age'].mode(), columns=['Most Common Age'])
#
# AttributeError: module 'datetime' has no attribute 'Now'

# %% [markdown]
# What’s the average number of bikes at a given bike station?

# %%
station = trip_df.groupby('from_station_name').mean()
bikeid = (trip_df['bikeid']).value_counts().mean()
list([station, bikeid])

# %% [markdown]
# When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %% [markdown]
# Note: not null part is very useful to see how many nulls are there in data, so we use info to check

# %%
station_df['modification_date'] = station_df['modification_date'].notnull()
station_df.modification_date

# %%
modified = station_df[['station_id', 'modification_date', 'install_dockcount', 'current_dockcount']]
filtered = modified.query('modification_date')
filtered[filtered['current_dockcount']>0]
